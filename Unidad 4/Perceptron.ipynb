# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
c = np.array([-40, -10,  0,  8, 15, 22,  38],  dtype=float)
f = np.array([-40,  14, 32, 46, 59, 72, 100],  dtype=float)

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Dense(units=1, input_shape=[1])
])

# %%
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.1), metrics=['mean_squared_error'])

# %%
history = model.fit(c, f, epochs=500, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model

# %%
history.params
# Out:
# {'verbose': False, 'epochs': 500, 'steps': 1}

# %%
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])
plt.show()

# %%
print("Prediccion")
print(model.predict([100.0]))
print("-------------")
print("Con formula a mano")
formula_a_mano = (100*1.8)+32
print(formula_a_mano)
# Out:
# Prediccion
# 1/1 [==============================] - 0s 49ms/step
# [[211.3332]]
# -------------
# Con formula a mano
# 212.0
